# %% [markdown]
# # Road Ban Restrictions Analysis

# %% [markdown]
# ## Objective

# %% [markdown]
# The objective of this script is to extract the road ban data from the available pdfs on the Alberta Open Data website and attempt to build analytics regarding the historical start dates for road bans. The analytics can help people gain a better statistical understanding of when road bans will be in effect and the degree in which it is the case.
#
# The analytics will examine the frequency of effective dates for axles weights at 75%, 90%, 100%. The data will be normalized to the calendar year to provide insight as to how when road ban restrictions come into effect on the calendar year. The assumption is that these bans are based on weather and temperatures which is correlated with the time of the year in which they get placed.
#
# Further analysis can be done to examine trends over time to see if there are any longitudinal trends regarding the road ban timing over time.

# %% [markdown]
# ## Why is this important?
# Transportation of goods and services are a critical part of supply chain within the oil and gas, forestry, and agricultural industries. Project logistics and costs heavily are impacted by capabilities of being able to transport necessary equipment to project sites. Understanding restrictions and the timing of information can lead to a better understanding of project risks and aid project planners and managers with tangible data to make better decisions.
#
# Properly understanding project risks can have a significant impact on proper capital management. Being handcuffed by road ban restrictions can lead to project delays and increased costs to either increase truck traffic to reduce loads and/or upgrade and repair roads that get damaged by heavy traffic in poor conditions.

# %% [markdown]
# # Script

# %% [markdown]
# ## Setup

# %%
import PyPDF2
import re
import pandas as pd
import numpy as np
import datetime as dt
import os
from tabula.io import read_pdf
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

# %%
# Transportation Road Ban Summary List Reports
# Available at: ENTER URL HERE FOR THE REPORTS
summary_lists = os.listdir('./road ban summary lists')
summary_lists
# Out:
# ['trans-2014-road-ban-summary-list.pdf',
#  'trans-2015-road-ban-summary-list.pdf',
#  'trans-2016-road-ban-summary-list.pdf',
#  'trans-2017-road-ban-summary-list.pdf',
#  'trans-2018-road-ban-summary-list.pdf',
#  'trans-2019-road-ban-summary-list.pdf',
#  'trans-2020-road-ban-summary-list.pdf']

# %% [markdown]
# ## Attempting to parse the pdf with PyPDF2
# Attempting to parse the information using PyPDF2 library; however, due to the structure of the parsed results, it is very difficult to be able to do the data cleaning into a form that will be easily manipulatable.

# %%
pdfFileObj = open('./road ban summary lists/trans-2020-road-ban-summary-list.pdf','rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
text = []
for page in range(pdfReader.numPages):
    page = pdfReader.getPage(page).extractText()
    page = re.split(f'Page [0-9]+ of {pdfReader.numPages}',page)
#     text.append(page.split(f'Page [0-9]+ of {pdfReader.numPages}',page))
#     text.append(page)
    text.append(page[1])
#     print(page)
text
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
# ['RoadDescriptionDistanceEffective DatePercentageJamieson Road1A1A10X10X222540404040Jct. 1A - 2.3 km North (Stoney Indian Reserve #144 North Boundary)0.6 km East of Jct 1X - Jamieson Road (8.0 km West of Jct. 40)Jamieson Road (8.0 km West of Jct. 40) - Ghost Lake Provincial Recreation Areakm 0.05 (Bridge #9 at Wayne) - km 4.05 (Bridge #2)km 4.05 (Bridge #2) - km 5.61 (Jct. 10)Mayerthorpe - Jct. 18Jct. 521 - Jct. 526Cadomin Jct. (47.9 km S. of Jct. 16) - Teck Coal Cardinal Ops Access Rd(39.9 km S. of Jct. 16)Cadomin Junction
jct. 12)Urban Access Road 111 (Jct. 12 - Clive)April 13, 2020June 11, 2020May 27, 2019March 2, 2020June 4, 2020June 14, 2012February 20, 2013May 30, 2019March 6, 2020June 4, 2020May 30, 2019March 6, 2020June 4, 2020May 30, 2019March 6, 2020June 4, 2020March 2, 2020June 4, 2020April 8, 2008March 8, 2012May 13, 2019November 26, 2020May 30, 2019March 6, 2020June 4, 2020February 4, 201690%Lifted90%75%90%75%90%90%75%90%90%75%90%90%75%90%90%Lifted75%75%75%Lifted90%75%90%75%27.1 km29.9 km29.9 km16 km53.2 km19.5 km53.1 km39 km9.9 km4.4 km28.6 km46.1 km1.1 km',
#  'RoadDescriptionDistanceEffective DatePercentageUAR 187Calling Lake DriveEnglish Bay RoadFLMM - 8.5 km EastGurneyville RoadNikoodi RoadOiled RoadsRange Road 24Swan River IRUrban Access Road 187 (Jct. 21 - Swalwell)Calling Lake Drive in the Jean Baptiste Gambler Indian Reserve #183English Bay Road through the Cold Lake Indian Reserve #149BFrog Lake Massacre Monument - 8.5 km East in the Unipauheos Indian Reserve #121Gurneyville Road from Jct. 657 North in the Kehewin Indian Reserve #123Nikoodi Road Through the Alexis Indian Reserve #133Oiled Roads as posted in the Jean Baptiste Gambler Indian Reserve #183Jct. 897 to Jct. 28 in the Cold Lake Indian Reserve #149Roads as posted, in the Swan River Indian Reserve #150EFebruary 4, 2016April 13, 2020February 4, 2016February 4, 2016February 4, 2016June 17, 2019February 4, 2016April 13, 2020June 18, 2020April 24, 2020June 11, 202075%75%75%75%75%75%75%75%Lifted75%Lifted5.5 km2 km8.5 km9 km13 km']

# %%
pdfReader.getPage(0)['/Parent']['/Kids'][0]
# Out:
# IndirectObject(28, 0)

# %%
pdfReader.getDocumentInfo()
# Out:
# {'/Author': 'Government of Alberta – Ministry of Transportation',
#  '/CreationDate': 'D:20210219091436Z',
#  '/Creator': 'Oracle11gR1 AS Reports Services',
#  '/Keywords': 'Security Classification: PUBLIC',
#  '/ModDate': "D:20210317161912-06'00'",
#  '/Producer': 'Oracle PDF driver',
#  '/Subject': '2020 road bans, 2020 provincial road bans, 2020 road ban summary',
#  '/Title': '2020 Road Ban Summary'}

# %%
pdfReader.getXmpMetadata()

# %%
pdfReader.documentInfo
# Out:
# {'/Author': 'Government of Alberta – Ministry of Transportation',
#  '/CreationDate': 'D:20210219091436Z',
#  '/Creator': 'Oracle11gR1 AS Reports Services',
#  '/Keywords': 'Security Classification: PUBLIC',
#  '/ModDate': "D:20210317161912-06'00'",
#  '/Producer': 'Oracle PDF driver',
#  '/Subject': '2020 road bans, 2020 provincial road bans, 2020 road ban summary',
#  '/Title': '2020 Road Ban Summary'}

# %% [markdown]
# ## Using Tabula to parse tables from pdfs
# The tabula library was more successful in parsing the information into a state that is much easier to manipulate using pandas and regular expressions.
#
# Upon parsing the data from the various files, there are noticeably a few different formats over the years from the Alberta road ban data distribution. We will need to address them individually in order to normalize and structure the data to be usable for further analysis.

# %% [markdown]
# ## Format 1: 2004 - 2013
# Individual reports that are issued non-regularly stating the status of roads for that given report period. Multiple reports for each year are available.

# %%
# List of individual road ban reports
rb_reports = os.listdir('./road ban reports/')
rb_reports
# Out:
# ['trans-2004-road-bans-15.pdf',
#  'trans-2004-road-bans-17.pdf',
#  'trans-2004-road-bans-18.pdf',
#  'trans-2004-road-bans-19.pdf',
#  'trans-2004-road-bans-20.pdf',
#  'trans-2004-road-bans-21.pdf',
#  'trans-2004-road-bans-22.pdf',
#  'trans-2004-road-bans-23.pdf',
#  'trans-2004-road-bans-24.pdf',
#  'trans-2004-road-bans-25.pdf',
#  'trans-2004-road-bans-26.pdf',
#  'trans-2004-road-bans-27.pdf',
#  'trans-2004-road-bans-28.pdf',
#  'trans-2004-road-bans-29.pdf',
#  'trans-2004-road-bans-30.pdf',
#  'trans-2004-road-bans-31.pdf',
#  'trans-2004-road-bans-32.pdf',
#  'trans-2004-road-bans-33.pdf',
#  'trans-2004-road-bans-34.pdf',
#  'trans-2004-road-bans-35.pdf',
#  'trans-2004-road-bans-37.pdf',
#  'trans-2004-road-bans-38.pdf',
#  'trans-2004-road-bans-39.pdf',
#  'trans-2004-road-bans-40.pdf',
#  'trans-2005-road-bans-1.pdf',
#  'trans-2005-road-bans-10.pdf',
#  'trans-2005-road-bans-11.pdf',
#  'trans-2005-road-bans-12.pdf',
#  'trans-2005-road-bans-13.pdf',
#  'trans-2005-road-bans-14.pdf',
#  'trans-2005-road-bans-15.pdf',
#  'trans-2005-road-bans-16.pdf',
#  'trans-2005-road-bans-17.pdf',
#  'trans-2005-road-bans-18.pdf',
#  'trans-2005-road-bans-19.pdf',
#  'trans-2005-road-bans-2.pdf',
#  'trans-2005-road-bans-20.pdf',
#  'trans-2005-road-bans-21.pdf',
#  'trans-2005-road-bans-22.pdf',
#  'trans-2005-road-bans-23.pdf',
#  'trans-2005-road-bans-24.pdf',
#  'trans-2005-road-bans-25.pdf',
#  'trans-2005-road-bans-26.pdf',
#  'trans-2005-road-bans-27.pdf',
#  'trans-2005-road-bans-28.pdf',
#  'trans-2005-road-bans-29.pdf',
#  'trans-2005-road-bans-3.pdf',
#  'trans-2005-road-bans-30.pdf',
#  'trans-2005-road-bans-31.pdf',
#  'trans-2005-road-bans-32.pdf',
#  'trans-2005-road-bans-33.pdf',
#  'trans-2005-road-bans-34.pdf',
#  'trans-2005-road-bans-35.pdf',
#  'trans-2005-road-bans-36.pdf',
#  'trans-2005-road-bans-37.pdf',
#  'trans-2005-road-bans-38.pdf',
#  'trans-2005-road-bans-39.pdf',
#  'trans-2005-road-bans-4.pdf',
#  'trans-2005-road-bans-40.pdf',
#  'trans-2005-road-bans-41.pdf',
#  'trans-2005-road-bans-42.pdf',
#  'trans-2005-road-bans-43.pdf',
#  'trans-2005-road-bans-44.pdf',
#  'trans-2005-road-bans-45.pdf',
#  'trans-2005-road-bans-46.pdf',
#  'trans-2005-road-bans-47.pdf',
#  'trans-2005-road-bans-48.pdf',
#  'trans-2005-road-bans-49.pdf',
#  'trans-2005-road-bans-5.pdf',
#  'trans-2005-road-bans-50.pdf',
#  'trans-2005-road-bans-51.pdf',
#  'trans-2005-road-bans-52.pdf',
#  'trans-2005-road-bans-53.pdf',
#  'trans-2005-road-bans-54.pdf',
#  'trans-2005-road-bans-55.pdf',
#  'trans-2005-road-bans-6.pdf',
#  'trans-2005-road-bans-7.pdf',
#  'trans-2005-road-bans-8.pdf',
#  'trans-2005-road-bans-9.pdf',
#  'trans-2006-road-bans-1.pdf',
#  'trans-2006-road-bans-10.pdf',
#  'trans-2006-road-bans-11.pdf',
#  'trans-2006-road-bans-12.pdf',
#  'trans-2006-road-bans-13.pdf',
#  'trans-2006-road-bans-14.pdf',
#  'trans-2006-road-bans-15.pdf',
#  'trans-2006-road-bans-16.pdf',
#  'trans-2006-road-bans-18.pdf',
#  'trans-2006-road-bans-19.pdf',
#  'trans-2006-road-bans-2.pdf',
#  'trans-2006-road-bans-20.pdf',
#  'trans-2006-road-bans-21.pdf',
#  'trans-2006-road-bans-22.pdf',
#  'trans-2006-road-bans-23.pdf',
#  'trans-2006-road-bans-24.pdf',
#  'trans-2006-road-bans-25.pdf',
#  'trans-2006-road-bans-26.pdf',
#  'trans-2006-road-bans-27.pdf',
#  'trans-2006-road-bans-28.pdf',
#  'trans-2006-road-bans-29.pdf',
#  'trans-2006-road-bans-3.pdf',
#  'trans-2006-road-bans-30.pdf',
#  'trans-2006-road-bans-31.pdf',
#  'trans-2006-road-bans-32.pdf',
#  'trans-2006-road-bans-33.pdf',
#  'trans-2006-road-bans-34.pdf',
#  'trans-2006-road-bans-35.pdf',
#  'trans-2006-road-bans-36.pdf',
#  'trans-2006-road-bans-37.pdf',
#  'trans-2006-road-bans-38.pdf',
#  'trans-2006-road-bans-39.pdf',
#  'trans-2006-road-bans-4.pdf',
#  'trans-2006-road-bans-40.pdf',
#  'trans-2006-road-bans-41.pdf',
#  'trans-2006-road-bans-42.pdf',
#  'trans-2006-road-bans-5.pdf',
#  'trans-2006-road-bans-6.pdf',
#  'trans-2006-road-bans-7.pdf',
#  'trans-2006-road-bans-8.pdf',
#  'trans-2006-road-bans-9.pdf',
#  'trans-2007-road-bans-1.pdf',
#  'trans-2007-road-bans-10.pdf',
#  'trans-2007-road-bans-11.pdf',
#  'trans-2007-road-bans-12.pdf',
#  'trans-2007-road-bans-13.pdf',
#  'trans-2007-road-bans-14.pdf',
#  'trans-2007-road-bans-15.pdf',
#  'trans-2007-road-bans-16.pdf',
#  'trans-2007-road-bans-17.pdf',
#  'trans-2007-road-bans-18.pdf',
#  'trans-2007-road-bans-19.pdf',
#  'trans-2007-road-bans-2.pdf',
#  'trans-2007-road-bans-20.pdf',
#  'trans-2007-road-bans-21.pdf',
#  'trans-2007-road-bans-22.pdf',
#  'trans-2007-road-bans-23.pdf',
#  'trans-2007-road-bans-24.pdf',
#  'trans-2007-road-bans-25.pdf',
#  'trans-2007-road-bans-26.pdf',
#  'trans-2007-road-bans-27.pdf',
#  'trans-2007-road-bans-28.pdf',
#  'trans-2007-road-bans-29.pdf',
#  'trans-2007-road-bans-3.pdf',
#  'trans-2007-road-bans-30.pdf',
#  'trans-2007-road-bans-31.pdf',
#  'trans-2007-road-bans-32.pdf',
#  'trans-2007-road-bans-33.pdf',
#  'trans-2007-road-bans-34.pdf',
#  'trans-2007-road-bans-35.pdf',
#  'trans-2007-road-bans-36.pdf',
#  'trans-2007-road-bans-37.pdf',
#  'trans-2007-road-bans-38.pdf',
#  'trans-2007-road-bans-39.pdf',
#  'trans-2007-road-bans-4.pdf',
#  'trans-2007-road-bans-40.pdf',
#  'trans-2007-road-bans-41.pdf',
#  'trans-2007-road-bans-42.pdf',
#  'trans-2007-road-bans-43.pdf',
#  'trans-2007-road-bans-44.pdf',
#  'trans-2007-road-bans-45.pdf',
#  'trans-2007-road-bans-46.pdf',
#  'trans-2007-road-bans-47.pdf',
#  'trans-2007-road-bans-5.pdf',
#  'trans-2007-road-bans-6.pdf',
#  'trans-2007-road-bans-7.pdf',
#  'trans-2007-road-bans-8.pdf',
#  'trans-2007-road-bans-9.pdf',
#  'trans-2008-road-bans-1.pdf',
#  'trans-2008-road-bans-10.pdf',
#  'trans-2008-road-bans-11.pdf',
#  'trans-2008-road-bans-12.pdf',
#  'trans-2008-road-bans-13.pdf',
#  'trans-2008-road-bans-14.pdf',
#  'trans-2008-road-bans-15.pdf',
#  'trans-2008-road-bans-16.pdf',
#  'trans-2008-road-bans-17.pdf',
#  'trans-2008-road-bans-18.pdf',
#  'trans-2008-road-bans-19.pdf',
#  'trans-2008-road-bans-2.pdf',
#  'trans-2008-road-bans-20.pdf',
#  'trans-2008-road-bans-21.pdf',
#  'trans-2008-road-bans-22.pdf',
#  'trans-2008-road-bans-23.pdf',
#  'trans-2008-road-bans-24.pdf',
#  'trans-2008-road-bans-25.pdf',
#  'trans-2008-road-bans-26.pdf',
#  'trans-2008-road-bans-27.pdf',
#  'trans-2008-road-bans-28.pdf',
#  'trans-2008-road-bans-29.pdf',
#  'trans-2008-road-bans-3.pdf',
#  'trans-2008-road-bans-30.pdf',
#  'trans-2008-road-bans-31.pdf',
#  'trans-2008-road-bans-32.pdf',
#  'trans-2008-road-bans-33.pdf',
#  'trans-2008-road-bans-33a.pdf',
#  'trans-2008-road-bans-34.pdf',
#  'trans-2008-road-bans-35.pdf',
#  'trans-2008-road-bans-36.pdf',
#  'trans-2008-road-bans-37.pdf',
#  'trans-2008-road-bans-38.pdf',
#  'trans-2008-road-bans-39.pdf',
#  'trans-2008-road-bans-4.pdf',
#  'trans-2008-road-bans-40.pdf',
#  'trans-2008-road-bans-41.pdf',
#  'trans-2008-road-bans-42.pdf',
#  'trans-2008-road-bans-43.pdf',
#  'trans-2008-road-bans-44.pdf',
#  'trans-2008-road-bans-45.pdf',
#  'trans-2008-road-bans-46.pdf',
#  'trans-2008-road-bans-5.pdf',
#  'trans-2008-road-bans-6.pdf',
#  'trans-2008-road-bans-7.pdf',
#  'trans-2008-road-bans-8.pdf',
#  'trans-2008-road-bans-9.pdf',
#  'trans-2009-road-bans-1.pdf',
#  'trans-2009-road-bans-10.pdf',
#  'trans-2009-road-bans-11.pdf',
#  'trans-2012-road-bans-39.pdf',
#  'trans-2012-road-bans-4.pdf',
#  'trans-2012-road-bans-40.pdf',
#  'trans-2012-road-bans-41.pdf',
#  'trans-2012-road-bans-42.pdf',
#  'trans-2012-road-bans-43.pdf',
#  'trans-2012-road-bans-44.pdf',
#  'trans-2012-road-bans-45.pdf',
#  'trans-2012-road-bans-5.pdf',
#  'trans-2012-road-bans-6.pdf',
#  'trans-2012-road-bans-7.pdf',
#  'trans-2012-road-bans-8.pdf',
#  'trans-2012-road-bans-9.pdf',
#  'trans-2013-road-bans-1.pdf',
#  'trans-2013-road-bans-10.pdf',
#  'trans-2013-road-bans-11.pdf',
#  'trans-2013-road-bans-12.pdf',
#  'trans-2013-road-bans-13.pdf',
#  'trans-2013-road-bans-14.pdf',
#  'trans-2013-road-bans-15.pdf',
#  'trans-2013-road-bans-16.pdf',
#  'trans-2013-road-bans-17.pdf',
#  'trans-2013-road-bans-18.pdf',
#  'trans-2013-road-bans-19.pdf',
#  'trans-2013-road-bans-2.pdf',
#  'trans-2013-road-bans-20.pdf',
#  'trans-2013-road-bans-21.pdf',
#  'trans-2013-road-bans-22.pdf',
#  'trans-2013-road-bans-23.pdf',
#  'trans-2013-road-bans-24.pdf',
#  'trans-2013-road-bans-25.pdf',
#  'trans-2013-road-bans-26.pdf',
#  'trans-2013-road-bans-27.pdf',
#  'trans-2013-road-bans-28.pdf',
#  'trans-2013-road-bans-29.pdf',
#  'trans-2013-road-bans-3.pdf',
#  'trans-2013-road-bans-30.pdf',
#  'trans-2013-road-bans-31.pdf',
#  'trans-2013-road-bans-32.pdf',
#  'trans-2013-road-bans-33.pdf',
#  'trans-2013-road-bans-34.pdf',
#  'trans-2013-road-bans-35.pdf',
#  'trans-2013-road-bans-4.pdf',
#  'trans-2013-road-bans-5.pdf',
#  'trans-2013-road-bans-6.pdf',
#  'trans-2013-road-bans-7.pdf',
#  'trans-2013-road-bans-8.pdf',
#  'trans-2013-road-bans-9.pdf',
#  'trans-2014-road-bans-36.pdf']

# %%
# Extracting the effective date from the parsed pdf report 
filename = 'trans-2013-road-bans-3.pdf'
pdfFileObj = open(f'./road ban reports/{filename}','rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
text = pdfReader.getPage(0).extractText()
eff_date = dt.datetime.strptime(', '.join([x for x in text.split('\n') if 'EFFECTIVE' in x][0].split('A.M. ')[-1].split(', ')[1:]),'%B %d, %Y')
print(eff_date)
# Out:
# 2013-03-08 00:00:00

# %%
# Reading the pdf yields the following format
filename = 'trans-2013-road-bans-35.pdf'
tables = read_pdf(f'./road ban reports/{filename}',pages='all')
tables
# Out:
# [   HIGHWAY Unnamed: 0                            DESCRIPTION AXLE WEIGHT  \
#  0       1A          -  0.6 km East of Jct. 1X - Jamieson Road (8.0 km...
#  1      10X          -  km 0.05 (Bridge No. 9 at Wayne) - km 4.55 (in ...
#  2       25          -                                Jct. 521 - Jct. 526
#  3       40          -         Jct.1A - MD8 Boundary (7.8 km North of 1A)
#  4       40          -  7.8 km  North of Jct. 1A (MD 8 Boundary) - 24....
#  5      NaN        NaN                                    (Richards Road)
#  6       40          -  24.2 km (Richards Road) - 27.1 km (Forest Rese...
#  7      500          -  Range Road 153A (km 0.4) - Range Road 135 (km ...
#  8      501          -                     4.4 km East of Jct. 5 - Jct. 2
#  9      501          -                                Jct. 500 - Jct. 879
#  10     505          -                               Belly River - Jct. 2
#  11     506          -                    Range Road 200 - Range Road 193
#  12     506          -   Range Road 193 (17.5 km West of Jct. 4) - Jct. 4
#  13     520          -     Range Road 283 - Claresholm Industrial Airport
#  14     521          -                   Jct. 25 - 3.2 km East of Jct. 25
#  15     521          -               3.2 km East of of Jct. 25 - Jct. 864
#  16     524          -                                Jct. 864 - Vauxhall
#  17     563          -           Jct. 1 (km 0) - The Burnco Pit (km 5.35)
#  18     633          -                           Range Road 14 - Jct. 779
#  19     633          -                            Jct. 43 - Range Road 20
#  20     762          -                                 Jct. 549 - Jct. 22
#  21     766          -                                Jct. 580 - Jct. 582
#  22     766          -                 Jct. 27 - Red Deer County Boundary
#  23     766          -                                 Jct. 582 - Jct. 27
#  24     766          -  Red Deer County South Boundary - Township Road...
#
#      Unnamed: 1
#  0         90.0
#  1         90.0
#  2         75.0
#  3         90.0
#  4         90.0
#  5          NaN
#  6         90.0
#  7         75.0
#  8         90.0
#  9         90.0
#  10        90.0
#  11        75.0
#  12        75.0
#  13        90.0
#  14        75.0
#  15        75.0
#  16        90.0
#  17        75.0
#  18        90.0
#  19        90.0
#  20        75.0
#  21        90.0
#  22        75.0
#  23        75.0
#  24        75.0  ,
#      772  -                                 Calgary - Jct. 566  75
#  0   791  -                       Jct. 590 - Township Road 364  75
#  1   824  -                                 Jct. 14 - Jct. 630  90
#  2   830  -                                 Jct. 630 - Jct. 16  90
#  3   831  -              Jct. 15 - Jct. 29 (In Town of Lamont)  75
#  4   836  -  Township Road 292A (km  10.93) - Parkland Ave....  75
#  5   842  -                  Jct. 1 - 5.4 km North of Jct. 561  75
#  6   846  -                                   Jct. 52 - Jct. 4  90
#  7   849  -  9.6 km North of Jct. 576 - 12.9 km North of Jc...  75
#  8   861  -           1 km North of The Battle River - Jct. 53  75
#  9   877  -  6.0 km South of Jct. 61 - 0.5 km South of Jct. 61  75
#  10  885  -                                 Jct. 501 - Jct. 61  75
#  11  885  -      km 16.0 (North of Jct. 61) - km 45.9 (Jct. 3)  75
#  12  885  -                              Jct. 61 - 16 km North  90
#  13  886  -                  Jct. 9 - 14.5 km South of Jct. 12  90
#  14  886  -                                Jct. 555 - Jct. 570  90
#  15  886  -                                  Jct. 570 - Jct. 9  90
#  16  889  -                  Jct. 61 - 4.4 km North of Jct. 61  75
#  17  889  -  4.4 km North of Jct. 61 - 14. 3 km North of Jc...  75
#  18  899  -                            Jct. 9 - km 33 (Esther)  75,
#     HIGHWAY Unnamed: 0            Unnamed: 1   PERCENTAGE
#  0      NO.        NaN           TO LOCATION  AXLE WEIGHT
#  1        1          -        Cluny (SH 842)          100
#  2      NaN          -              Gleichen          100
#  3        2          -                Berwyn          100
#  4      NaN          -   Blackfalds (SH 597)          100
#  5      NaN          -               Bluesky          100
#  6      NaN          -          Canyon Creek          100
#  7      NaN          -    Carstairs (SH 581)          100
#  8      NaN          -     Colinton (SH 663)          100
#  9      NaN          -     Didsbury (SH 582)          100
#  10     NaN          -              Donnelly          100
#  11     NaN          -                Enilda          100
#  12     NaN          -                 Faust          100
#  13     NaN          -       Granum (SH 519)          100
#  14     NaN          -              Joussard          100
#  15     NaN          -                Kinuso          100
#  16     NaN          -        Legal (SH 651)          100
#  17     NaN          -    Rochester (SH 661)          100
#  18     NaN          -                  Vimy          100
#  19     NaN          -               Wembley          100
#  20     NaN          -              Whitelaw          100
#  21     NaN          -             Widewater          100
#  22     NaN          -       Woking (SH 677)          100
#  23       3          -                  Kipp          100
#  24       9          -              Beiseker          100
#  25     NaN          -             Craigmyle          100
#  26     NaN          -        Delia (SH 851)          100
#  27     NaN          -              Irricana          100
#  28      11          -               Benalto          100
#  29     NaN          -     Eckville (SH 766)          100
#  30     NaN          -  Leslieville (SH 761)          100
#  31      12          -                 Clive           75
#  32     NaN          -                  Tees          100,
#        13  -                 Cadogan  100
#  0    NaN  -                  Gwynne  100
#  1    NaN  -               Hughenden  100
#  2    NaN  -                Metiskow  100
#  3    NaN  -               Sedgewick  100
#  4   14.0  -       Edgerton (SH 894)  100
#  5    NaN  -  Sherwood Park (SH 630)  100
#  6   15.0  -                 Minburn  100
#  7    NaN  -                Ranfurly  100
#  8   16.0  -               Evansburg  100
#  9    NaN  -   Hinton/Jasper Airport  100
#  10   NaN  -          Islay (SH 893)  100
#  11   NaN  -       Kitscoty (SH 897)  100
#  12  17.0  -        Chauvin (SH 610)  100
#  13  20.0  -                Bluffton  100
#  14   NaN  -                Winfield  100
#  15  21.0  -                  Bashaw  100
#  16   NaN  -         Carbon (SH 575)  100
#  17   NaN  -                Delburne  100
#  18   NaN  -                  Elnora  100
#  19   NaN  -               Hay Lakes  100
#  20   NaN  -                  Huxley  100
#  21   NaN  -                 Lousana  100
#  22   NaN  -             New Sarepta  100
#  23   NaN  -               Rockyford  100
#  24   NaN  -                Swalwell   75
#  25  22.0  -            Rocky Rapids  100
#  26  23.0  -        Blackie (SH 799)  100
#  27   NaN  -               Carmangay  100
#  28   NaN  -      Nobleford (SH 519)  100
#  29  27.0  -                  Morrin  100,
#        28  -                    Ashmont  100
#  0    NaN  -                     Bellis  100
#  1    NaN  -           Bonnyville Beach  100
#  2    NaN  -           Glendon (SH 882)  100
#  3    NaN  -                    Mallaig  100
#  4    NaN  -                     Radway  100
#  5    NaN  -                 Smoky Lake  100
#  6    NaN  -                St. Edouard  100
#  7    NaN  -                      Vilna  100
#  8    NaN  -                   Warspite  100
#  9    NaN  -        Waskatenau (SH 631)  100
#  10  32.0  -                      Peers  100
#  11  33.0  -  Fort Assiniboine (SH 661)  100
#  12  34.0  -                     DeBolt  100
#  13  35.0  -        Dixonville (SH 689)  100
#  14   NaN  -         High Level Airport  100
#  15  36.0  -          Alliance (SH 602)  100
#  16   NaN  -                    Galahad  100
#  17   NaN  -                     Kikino  100
#  18   NaN  -                    Scandia  100
#  19  39.0  -           Thorsby (SH 778)  100
#  20  41.0  -              Acadia Valley  100
#  21   NaN  -                       Czar  100
#  22   NaN  -                    Empress  100
#  23   NaN  -                      Hilda  100
#  24   NaN  -                New Brigden  100
#  25   NaN  -                    Schuler  100
#  26  43.0  -        Blue Ridge (SH 658)  100
#  27   NaN  -                     Onoway  100
#  28   NaN  -            Rochfort Bridge  100
#  29  44.0  -              Dapp (SH 661)  100
#  30   NaN  -                    Fawcett  100
#  31   NaN  -                   Flatbush   75
#  32   NaN  -                     Jarvie  100
#  33   NaN  -                    Pibroch  100,
#        45  -        Andrew (SH 855)  100
#  0    NaN  -             Clandonald  100
#  1    NaN  -                Derwent  100
#  2    NaN  -               Dewberry  100
#  3    NaN  -             Hairy Hill  100
#  4   47.0  -                   Robb  100
#  5   49.0  -     Eaglesham (SH 739)  100
#  6    NaN  -   Girouxville (SH 744)  100
#  7    NaN  -           Spirit River  100
#  8    NaN  -       Tangent (SH 740)  100
#  9   53.0  -       Alberta Hospital  100
#  10  54.0  -       Dickson (SH 766)  100
#  11  55.0  -     Plamondon (SH 858)  100
#  12   NaN  -              Rich Lake  100
#  13  56.0  -    Big Valley (SH 661)  100
#  14   NaN  -                 Rowley  100
#  15  61.0  -               Wrentham  100
#  16  63.0  -                  Boyle  100
#  17   NaN  -      Newbrook (SH 661)  100
#  18  69.0  -  Fort McMurray Airport  100
#  19  88.0  -        Fort Vermillion  100,
#    HIGHWAY Unnamed: 0                            DESCRIPTION AXLE WEIGHT  \
#  0  Local:          -  127 St. From the Ellerslie Road to Anthony Hen...
#  1     NaN        NaN                                           Edmonton
#  2  Local:          -  The English Bay Road through the Cold Lake Ind...
#  3     NaN        NaN                                              #149B
#  4  Local:          -  The Gurneyville Road from SH 657 North in the ...
#  5     NaN        NaN                                       Reserve #123
#  6  Local:          -  Oiled Roads as posted in the Calling Lake Indi...
#  7  Local:          -  The Frog Lake Massacre Monument - 8.5 km East ...
#  8     NaN        NaN                     Unipauheos Indian Reserve #121
#  9  Local:          -  The Nikoodi Road through the Alexis Indian Res...
#
#     Unnamed: 1
#  0        75.0
#  1         NaN
#  2        75.0
#  3         NaN
#  4        75.0
#  5         NaN
#  6        75.0
#  7        75.0
#  8         NaN
#  9        75.0  ]

# %%
# First dataframe based on the pdf data extraction
df3 = pd.DataFrame()
for i in range(len(tables)):
    df3 = pd.concat([df3,tables[i].T.reset_index().T])
df3 = df3.iloc[1:].drop_duplicates()
df3.columns = ['Road','-','Description','Percentage']
df3.drop('-',axis=1,inplace=True)
df3
# This version has a simple flaw that wrapped text ended up having extra rows that are split up the description
# Out:
#       Road                                        Description Percentage
# 0       1A  0.6 km East of Jct. 1X - Jamieson Road (8.0 km...         90
# 1      10X  km 0.05 (Bridge No. 9 at Wayne) - km 4.55 (in ...         90
# 2       25                                Jct. 521 - Jct. 526         75
# 3       40         Jct.1A - MD8 Boundary (7.8 km North of 1A)         90
# 4       40  7.8 km  North of Jct. 1A (MD 8 Boundary) - 24....         90
# ..     ...                                                ...        ...
# 5      NaN                                       Reserve #123        NaN
# 6   Local:  Oiled Roads as posted in the Calling Lake Indi...         75
# 7   Local:  The Frog Lake Massacre Monument - 8.5 km East ...         75
# 8      NaN                     Unipauheos Indian Reserve #121        NaN
# 9   Local:  The Nikoodi Road through the Alexis Indian Res...         75
#
# [177 rows x 3 columns]

# %%
# Script to 
data = []
# Iterates through the pages of the pdf
for i in range(len(tables)):
    df_temp = tables[i]
    df_temp.columns = ['Road','-','Description','Percentage']
    # Iterating through each rows
    for index, row in df_temp.iterrows():
        # Checks if the index goes out of scope because we want to look ahead a row for wrapped text
        if index < len(df_temp)-1:
            if pd.notnull(row['Road']):
                # If the following row does not have an actual entry, then it is wrapped text and adds the description to the current row
                if pd.isnull(df_temp.iloc[index+1]['Road']):
                    data.append([row['Road'],row['Description']+df_temp.iloc[index+1]['Description'],row['Percentage']])
                else:
                    # Eliminates the row with column headers
                    if row['Percentage'] == 'AXLE WEIGHT':
                        continue
                    data.append([row['Road'],row['Description'],row['Percentage']])
        # Skips the row if the row is wrapped text
        if pd.isnull(row['Road']):
            continue
df3 = pd.DataFrame(data,columns=['Road','Description','Percentage'])
df3
# Out:
#       Road                                        Description Percentage
# 0       1A  0.6 km East of Jct. 1X - Jamieson Road (8.0 km...         90
# 1      10X  km 0.05 (Bridge No. 9 at Wayne) - km 4.55 (in ...         90
# 2       25                                Jct. 521 - Jct. 526         75
# 3       40         Jct.1A - MD8 Boundary (7.8 km North of 1A)         90
# 4       40  7.8 km  North of Jct. 1A (MD 8 Boundary) - 24....         90
# ..     ...                                                ...        ...
# 73  Local:  127 St. From the Ellerslie Road to Anthony Hen...         75
# 74  Local:  The English Bay Road through the Cold Lake Ind...         75
# 75  Local:  The Gurneyville Road from SH 657 North in the ...         75
# 76  Local:  Oiled Roads as posted in the Calling Lake Indi...         75
# 77  Local:  The Frog Lake Massacre Monument - 8.5 km East ...         75
#
# [78 rows x 3 columns]

# %% [markdown]
# ## Format 2: 2014 to 2017
# Tabular format with effective dates of the various restrictions in independent columns.

# %%
# Reading the pdf yields the following format
filename = 'trans-2016-road-ban-summary-list.pdf'
tables = read_pdf(f'./road ban summary lists/{filename}',pages='all')
tables
# Out:
# [   2016 Alberta Transportation Road Bans  \
#  0                                Highway
#  1                             127 Street
#  2                            Jamieson Rd
#  3                                     1A
#  4                                     1A
#  5                                     2A
#  6                                    10X
#  7                                    10X
#  8                                     22
#  9                                     25
#  10                                    40
#  11                                    40
#  12                                    40
#  13                                    40
#  14                                    40
#  15                                    40
#  16                                    40
#  17                                    40
#  18                                    41
#  19                                    56
#  20                                    66
#  21                                   500
#  22                                   501
#  23                                   501
#  24                                   501
#  25                                   501
#  26                                   501
#  27                                   505
#  28                                   505
#  29                                   506
#  30                                   506
#  31                                   507
#  32                                   507
#  33                                   508
#  34                                   509
#  35                                   512
#  36                                   519
#  37                                   519
#
#                                             Unnamed: 0  Unnamed: 1 Unnamed: 2  \
#  0                                             Section  Dist. (km)        75%
#  1   Ellerslie Road to Anthony Henday Drive in Edmo...         0.9   all year
#  2   Jct. 1A - 2.3 km North (Stoney Indian Reserve ...         2.3    Apr. 24
#  3   0.6 km East of Jct. 1X - Jamieson Road (Range ...        27.9    Feb. 11
#  4   Jamieson Road (Range Road 64A - 8.14 km West o...         3.7    Apr. 24
#  5       Township Road 834 - Range Road 234 (Grimshaw)         8.1        NaN
#  6   km 0.05 (bridge #9 at Wayne) - km 4.05 (Bridge...         4.5     Mar. 7
#  7             km 4.05 (Bridge #2) - km 5.61 (Jct. 10)         1.1     Mar. 7
#  8                               Mayerthorpe - Jct. 18         6.9     Mar. 7
#  9                                 Jct. 521 - Jct. 526        19.4   all year
#  10  Jct. 1A - The M.D. 8 Boundary (7.8 km North of...         7.8    Feb. 11
#  11  7.8 km North of Jct. 1A (MD 8 Boundary) - 23.9...        16.1    Feb. 11
#  12  23.9 km North of Jct. 1A (Richards Road) - 27....         3.2    Feb. 11
#  13  Jct. 734 - 19.5 km South of Jct. 47 (100 metre...        16.6        NaN
#  14                 19.5 km South of Jct. 47 - Jct. 47        35.7    Mar. 14
#  15  Cadomin Junction  (47.9 km South of Jct. 16) -...        29.4        NaN
#  16  Cadomin Junction  (47.9 km South of Jct. 16) -...         8.0        NaN
#  17  Cutbank River (63 km South of Grande Prairie) ...        31.1    Mar. 24
#  18                                 Jct. 29 - Jct. 657        15.9    Mar. 10
#  19                                  Jct. 9 - Stettler        73.7        NaN
#  20                               Ford Creek - Jct. 22        27.5        NaN
#  21  Range Road 153A (km 0.4) - Range Road 135 (km ...        19.4   all year
#  22                                    Jct. 5 - Jct. 2        20.3    Feb. 11
#  23                                   Jct. 62 - Jct. 4        59.0    Feb. 11
#  24                                  Jct. 2 - Jct. 820        23.3        NaN
#  25                                  Jct. 4 - Jct. 500        10.2    Feb. 11
#  26                                Jct. 500 - Jct. 879        19.7    Feb. 11
#  27  Gulf Plant Access Road (Range Road 292) - Wate...        16.9        NaN
#  28      Waterton River - Range Road 271 (by Glenwood)        12.9        NaN
#  29                    Range Road 200 - Range Road 193         5.4   all year
#  30   Range Road 193 (17.4 km West of Jct. 4) - Jct. 4        17.5   all year
#  31                             Jct. 3 - Pincher Creek        33.1        NaN
#  32  Pincher Creek - 1.6 km West of Jct. 786 (Range...        14.2    Feb. 11
#  33                                    Jct. 5 - Jct. 4         8.3    Feb. 11
#  34  Jct. 2 - Range Road 240 (17.40 km East of Jct. 2)        17.4        NaN
#  35                              Lethbridge - Jct. 845        11.3        NaN
#  36                                Nobleford - Jct. 25        17.7        NaN
#  37                           Picture Butte - Jct. 845        12.2        NaN
#
#     Unnamed: 3 Unnamed: 4
#  0         90%    Ban Off
#  1         NaN        NaN
#  2         NaN    May. 16
#  3      May 16        NaN
#  4         NaN    May. 16
#  5     Mar. 14        NaN
#  6      May 16        NaN
#  7         NaN    May. 16
#  8         NaN     Jun. 6
#  9         NaN        NaN
#  10     May 16        NaN
#  11     May 16        NaN
#  12     May 16        NaN
#  13    Mar. 14    May. 30
#  14        NaN    May. 30
#  15    Mar. 14    Jun. 16
#  16    Mar. 14    May. 30
#  17        NaN    Jun. 16
#  18        NaN    Dec. 12
#  19     Mar. 7    May. 30
#  20    Feb. 11    May. 16
#  21        NaN        NaN
#  22     May 16        NaN
#  23     May 16        NaN
#  24    Feb. 11    May. 16
#  25        NaN    May. 16
#  26     May 16        NaN
#  27    Feb. 11    May. 16
#  28    Feb. 11    May. 16
#  29        NaN        NaN
#  30        NaN        NaN
#  31    Feb. 11    May. 16
#  32        NaN    May. 16
#  33        NaN    May. 16
#  34    Feb. 11    May. 16
#  35    Feb. 11    May. 16
#  36    Feb. 11    May. 16
#  37    Feb. 11    May. 16  ,
#      Highway                                            Section  Dist. (km)  \
#  0       520     Range Road 283 - Claresholm Industrial Airport         7.4
#  1       521                  3.2 km East of Jct. 25 - Jct. 864        19.3
#  2       521                   Jct. 25 - 3.2 km East of Jct. 25         3.2
#  3       524                                Jct. 864 - Vauxhall         9.3
#  4       537                    Jct. 41 - Saskatchewan Boundary         6.5
#  5       540                               64 St. West - Jct. 2        18.9
#  6       544            Jct. 36 - 4.6 km East of Jct. 876 South        25.1
#  7       545                    Jct. 41 - Saskatchewan Boundary         6.5
#  8       561                                 Jct. 36 - Jct. 876        21.6
#  9       562                    Jct. 41 - Saskatchewan Boundary        13.6
#  10      563    Range Road  31 (km 0.62) - Burnco Pit (km 5.35)         4.7
#  11      570                                 Jct. 36 - Jct. 876        19.2
#  12      575  Jct. 791 - Kneehill County Boundary (Range Roa...        11.3
#  13      575  Jct. 836 (Carbon Access Road) - Hesketh turnof...        26.5
#  14      576                    Jct. 849 North - Jct. 851 North        14.8
#  15      582         5.6 km East of Jct. 22 - Didsbury (23 St.)        19.3
#  16      583                                Jct. 805 - Jct. 806         6.5
#  17      585  Trochu - Starland County Boundary (Red Deer Ri...        18.0
#  18      585  Jct. 836 - Starland County Boundary (Red Deer ...         5.0
#  19      586                                 Jct. 36 - Jct. 872        31.3
#  20      589                         Jct. 56 - Jct. 855 (South)        40.4
#  21      590  0.8 km East of the Innisfail Interchange - Jct...         7.6
#  22      607                                 Jct. 761 - Jct. 20        17.8
#  23      616                               Jct. 2 - 2A (Millet)         8.6
#  24      616                  3.2 km East of Jct. 822 - Jct. 21        13.9
#  25      628   Stony Plain - Golden Spike Road (Range Road 273)         4.0
#  26      628  0.29 km East of Jct. 60 (km 16.20) - Edmonton ...         3.2
#  27      631                           Jct. 36 - Jct. 870 North        16.3
#  28      633                            Jct. 43 - Range Road 20         4.8
#  29      633                           Range Road 14 - Jct. 779         6.4
#  30      645                                 Jct. 45 - Jct. 857         8.4
#  31      654                                 Jct. 764 - Jct. 33        17.7
#  32      655                            Jct. 763 - Mystery Lake         9.8
#  33      661   Fort Assiniboine - Range Road 55 (14.3 km North)        14.3
#  34      672                           Jct. 724 - Range Road 63        19.3
#  35      677            Jct. 724 (Township Road 762) - Jct. 731        12.8
#  36      677                                  Jct. 2 - Jct. 733        19.6
#  37      679                 6.9 km East of Jct. 749 - Jct. 750        27.1
#  38      680                                Jct. 725 - Jct. 727        14.7
#
#           75%       90%  Ban Off
#  0        NaN  all year      NaN
#  1   all year       NaN      NaN
#  2   all year       NaN      NaN
#  3        NaN  all year      NaN
#  4    Feb. 11       NaN  May. 16
#  5    Feb. 11       NaN  May. 16
#  6        NaN   Feb. 11  May. 16
#  7        NaN   Feb. 11  May. 16
#  8     Mar. 7       NaN  May. 16
#  9        NaN    Mar. 7  May. 16
#  10  all year       NaN      NaN
#  11    Mar. 7       NaN  May. 16
#  12   Feb. 11       NaN  May. 16
#  13       NaN    Mar. 7  May. 16
#  14    Mar. 7       NaN  May. 16
#  15       NaN   Feb. 11  May. 16
#  16       NaN    Mar. 7  May. 30
#  17       NaN    Mar. 7  May. 30
#  18   Sept. 1       NaN      NaN
#  19    Mar. 7       NaN  May. 16
#  20    Mar. 7       NaN  May. 30
#  21       NaN    Mar. 7  May. 30
#  22    Mar. 7       NaN  May. 30
#  23       NaN    Mar. 7  May. 30
#  24    Mar. 7       NaN  Dec. 19
#  25    Mar. 9       NaN  Dec. 19
#  26    Mar. 9       NaN      NaN
#  27    Mar. 7       NaN  May. 30
#  28       NaN    Mar. 7  Dec. 19
#  29       NaN    Mar. 7  Dec. 19
#  30  all year       NaN  Sept. 1
#  31       NaN    Mar. 7   Jun. 6
#  32       NaN    Mar. 7   Jun. 6
#  33       NaN    Mar. 7   Jun. 6
#  34   Mar. 14       NaN   Jun. 6
#  35   Mar. 14       NaN   Jun. 6
#  36   Mar. 14       NaN   Jun. 6
#  37   Jul. 20       NaN      NaN
#  38   Mar. 14       NaN   Jun. 6  ,
#      Highway                                            Section  Dist. (km)  \
#  0       681                  Jct. 719 - Jct. Township Road 814        23.0
#  1       684                       Jct. 2 (Grimshaw) - Jct. 740        12.8
#  2       689                           Range Road 260 - Jct. 35        22.5
#  3       719                                 Jct. 49 - Jct. 681        13.5
#  4       724  9.8 km North of Jct. 59 - Jct. 677 (Township R...        11.1
#  5       731                                 Jct. 677 - Jct. 49        21.0
#  6       734  56.7 km S. of Jct. 47 (Yellowhead County Bound...        25.0
#  7       752  Forest Reserve Boundary (Range Road 100) - Str...        23.1
#  8       752     Prairie Creek Road (Range Road 85A) - Jct. 11A        24.1
#  9       762                                 Jct. 549 - Jct. 22        22.2
#  10      763                                 Jct. 18 - Jct. 655        17.6
#  11      766                                Jct. 580 - Jct. 582        14.7
#  12      766                                 Jct. 582 - Jct. 27        14.6
#  13      766           Jct. 27 - Red Deer County South Boundary        14.6
#  14      766  Red Deer County South Boundary - Township Road...         9.7
#  15      766  Township Road 394 (North of Medicine River) - ...         3.3
#  16      771  Jct. 13 - 8.6 km North of Jct. 13 (Range Road 20)         9.0
#  17      772                Calgary North City Limit - Jct. 566         4.4
#  18      775                          Beauvais Lake to Jct. 507         8.0
#  19      777                                Jct. 642 - Jct. 651        16.1
#  20      791                                 Jct. 567 - Jct. 72         9.8
#  21      791  Red Deer County 23 South Boundary (0.8 km Sout...        14.7
#  22      791                  Jct. 590 - Jct. Township Road 364         9.7
#  32       NaN   Mar. 10   Jun. 6
#  33   Mar. 10       NaN   Jun. 6
#  34    Mar. 7       NaN  May. 30
#  35  all year       NaN      NaN
#  36       NaN  all year      NaN
#  37   Feb. 11    May 16      NaN
#  38    Mar. 7    May 16      NaN  ,
#      Highway                                            Section Dist. (km)  \
#  0       886                                  Jct. 570 - Jct. 9       19.5
#  1       886  Jct. 9 - 14.5 km South of Jct. 12 (Monitor Creek)       53.1
#  2       887                                   Jct. 61 - Jct. 3       50.8
#  3       889                  Jct. 61 - 4.4 km North of Jct. 61        4.4
#  4       889  4.4 km North of Jct. 61 - 14.3 km North of Jct...        9.9
#  5       899  Jct. 9 - 0.7 km north of Township Road 322 (18...       46.1
#  6   Access:                                 Jct. 21 - Swalwell        5.4
#  7   Access:                                    Jct. 12 - Clive        0.8
#  8    Local:    Nikoodi Road through Alexis Indian Reserve #133        N/A
#  9    Local:  The Gurneyville Road from Jct. 657 North in th...        N/A
#  10   Local:  The Frog lake Massacre Monument - 8.5 km East ...        N/A
#  11   Local:  The English Bay Road through the Cold Lake Ind...        N/A
#  12   Local:  Oiled Roads as posted,  in the Calling Lake In...        N/A
#  13   Local:  Roads as posted, in the Swan River Indian Rese...        N/A
#
#           75%      90%  Ban Off
#  0     Mar. 7   May 16      NaN
#  1     Mar. 7   May 16      NaN
#  2        NaN  Feb. 11  May. 16
#  3   all year      NaN      NaN
#  4   all year      NaN      NaN
#  5     Mar. 7   May 16      NaN
#  6   all year      NaN      NaN
#  7   all year      NaN      NaN
#  8   all year      NaN      NaN
#  9   all year      NaN      NaN
#  10  all year      NaN      NaN
#  11  all year      NaN      NaN
#  12  all year      NaN      NaN
#  13   Mar. 24      NaN   Jun. 6  ]

# %%
# Unformatted, the extracted table has the following form
pd.DataFrame(tables[0])
# Out:
#    2016 Alberta Transportation Road Bans  \
# 0                                Highway
# 1                             127 Street
# 2                            Jamieson Rd
# 3                                     1A
# 4                                     1A
# 5                                     2A
# 6                                    10X
# 7                                    10X
# 8                                     22
# 9                                     25
# 10                                    40
# 11                                    40
# 12                                    40
# 13                                    40
# 14                                    40
# 15                                    40
# 16                                    40
# 17                                    40
# 18                                    41
# 19                                    56
# 20                                    66
# 21                                   500
# 22                                   501
# 23                                   501
# 24                                   501
# 25                                   501
# 26                                   501
# 27                                   505
# 28                                   505
# 29                                   506
# 30                                   506
# 31                                   507
# 32                                   507
# 33                                   508
# 34                                   509
# 35                                   512
# 36                                   519
# 37                                   519
#
#                                            Unnamed: 0  Unnamed: 1 Unnamed: 2  \
# 0                                             Section  Dist. (km)        75%
# 1   Ellerslie Road to Anthony Henday Drive in Edmo...         0.9   all year
# 2   Jct. 1A - 2.3 km North (Stoney Indian Reserve ...         2.3    Apr. 24
# 3   0.6 km East of Jct. 1X - Jamieson Road (Range ...        27.9    Feb. 11
# 4   Jamieson Road (Range Road 64A - 8.14 km West o...         3.7    Apr. 24
# 5       Township Road 834 - Range Road 234 (Grimshaw)         8.1        NaN
# 6   km 0.05 (bridge #9 at Wayne) - km 4.05 (Bridge...         4.5     Mar. 7
# 7             km 4.05 (Bridge #2) - km 5.61 (Jct. 10)         1.1     Mar. 7
# 8                               Mayerthorpe - Jct. 18         6.9     Mar. 7
# 9                                 Jct. 521 - Jct. 526        19.4   all year
# 10  Jct. 1A - The M.D. 8 Boundary (7.8 km North of...         7.8    Feb. 11
# 11  7.8 km North of Jct. 1A (MD 8 Boundary) - 23.9...        16.1    Feb. 11
# 12  23.9 km North of Jct. 1A (Richards Road) - 27....         3.2    Feb. 11
# 13  Jct. 734 - 19.5 km South of Jct. 47 (100 metre...        16.6        NaN
# 14                 19.5 km South of Jct. 47 - Jct. 47        35.7    Mar. 14
# 15  Cadomin Junction  (47.9 km South of Jct. 16) -...        29.4        NaN
# 16  Cadomin Junction  (47.9 km South of Jct. 16) -...         8.0        NaN
# 17  Cutbank River (63 km South of Grande Prairie) ...        31.1    Mar. 24
# 18                                 Jct. 29 - Jct. 657        15.9    Mar. 10
# 19                                  Jct. 9 - Stettler        73.7        NaN
# 20                               Ford Creek - Jct. 22        27.5        NaN
# 21  Range Road 153A (km 0.4) - Range Road 135 (km ...        19.4   all year
# 22                                    Jct. 5 - Jct. 2        20.3    Feb. 11
# 23                                   Jct. 62 - Jct. 4        59.0    Feb. 11
# 24                                  Jct. 2 - Jct. 820        23.3        NaN
# 25                                  Jct. 4 - Jct. 500        10.2    Feb. 11
# 26                                Jct. 500 - Jct. 879        19.7    Feb. 11
# 27  Gulf Plant Access Road (Range Road 292) - Wate...        16.9        NaN
# 28      Waterton River - Range Road 271 (by Glenwood)        12.9        NaN
# 29                    Range Road 200 - Range Road 193         5.4   all year
# 30   Range Road 193 (17.4 km West of Jct. 4) - Jct. 4        17.5   all year
# 31                             Jct. 3 - Pincher Creek        33.1        NaN
# 32  Pincher Creek - 1.6 km West of Jct. 786 (Range...        14.2    Feb. 11
# 33                                    Jct. 5 - Jct. 4         8.3    Feb. 11
# 34  Jct. 2 - Range Road 240 (17.40 km East of Jct. 2)        17.4        NaN
# 35                              Lethbridge - Jct. 845        11.3        NaN
# 36                                Nobleford - Jct. 25        17.7        NaN
# 37                           Picture Butte - Jct. 845        12.2        NaN
#
#    Unnamed: 3 Unnamed: 4
# 0         90%    Ban Off
# 1         NaN        NaN
# 2         NaN    May. 16
# 3      May 16        NaN
# 4         NaN    May. 16
# 5     Mar. 14        NaN
# 6      May 16        NaN
# 7         NaN    May. 16
# 8         NaN     Jun. 6
# 9         NaN        NaN
# 10     May 16        NaN
# 11     May 16        NaN
# 12     May 16        NaN
# 13    Mar. 14    May. 30
# 14        NaN    May. 30
# 15    Mar. 14    Jun. 16
# 16    Mar. 14    May. 30
# 17        NaN    Jun. 16
# 18        NaN    Dec. 12
# 19     Mar. 7    May. 30
# 20    Feb. 11    May. 16
# 21        NaN        NaN
# 22     May 16        NaN
# 23     May 16        NaN
# 24    Feb. 11    May. 16
# 25        NaN    May. 16
# 26     May 16        NaN
# 27    Feb. 11    May. 16
# 28    Feb. 11    May. 16
# 29        NaN        NaN
# 30        NaN        NaN
# 31    Feb. 11    May. 16
# 32        NaN    May. 16
# 33        NaN    May. 16
# 34    Feb. 11    May. 16
# 35    Feb. 11    May. 16
# 36    Feb. 11    May. 16
# 37    Feb. 11    May. 16

# %%
year = int(filename.split('-')[1])

# Resets the column names to the first row
df = tables[0].T.reset_index(drop=True).set_index(0).T

# Setting the effective date to the first day of the year for all year restriction designations
df['75%'] = df['75%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
df['90%'] = df['90%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
df['Ban Off'] = df['Ban Off'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)

# Reformatting effective date data type from string to datetime
df['75%'] = df['75%'].apply(lambda x: dt.datetime.strptime(re.sub('\.','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
df['90%'] = df['90%'].apply(lambda x: dt.datetime.strptime(re.sub('\.','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
df['Ban Off'] = df['Ban Off'].apply(lambda x: dt.datetime.strptime(re.sub('\.','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
df
# Out:
# 0       Highway                                            Section Dist. (km)  \
# 1    127 Street  Ellerslie Road to Anthony Henday Drive in Edmo...        0.9
# 2   Jamieson Rd  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...        2.3
# 3            1A  0.6 km East of Jct. 1X - Jamieson Road (Range ...       27.9
# 4            1A  Jamieson Road (Range Road 64A - 8.14 km West o...        3.7
# 5            2A      Township Road 834 - Range Road 234 (Grimshaw)        8.1
# 6           10X  km 0.05 (bridge #9 at Wayne) - km 4.05 (Bridge...        4.5
# 7           10X            km 4.05 (Bridge #2) - km 5.61 (Jct. 10)        1.1
# 8            22                              Mayerthorpe - Jct. 18        6.9
# 9            25                                Jct. 521 - Jct. 526       19.4
# 10           40  Jct. 1A - The M.D. 8 Boundary (7.8 km North of...        7.8
# 11           40  7.8 km North of Jct. 1A (MD 8 Boundary) - 23.9...       16.1
# 12           40  23.9 km North of Jct. 1A (Richards Road) - 27....        3.2
# 13           40  Jct. 734 - 19.5 km South of Jct. 47 (100 metre...       16.6
# 14           40                 19.5 km South of Jct. 47 - Jct. 47       35.7
# 15           40  Cadomin Junction  (47.9 km South of Jct. 16) -...       29.4
# 16           40  Cadomin Junction  (47.9 km South of Jct. 16) -...        8.0
# 17           40  Cutbank River (63 km South of Grande Prairie) ...       31.1
# 18           41                                 Jct. 29 - Jct. 657       15.9
# 19           56                                  Jct. 9 - Stettler       73.7
# 20           66                               Ford Creek - Jct. 22       27.5
# 21          500  Range Road 153A (km 0.4) - Range Road 135 (km ...       19.4
# 22          501                                    Jct. 5 - Jct. 2       20.3
# 23          501                                   Jct. 62 - Jct. 4       59.0
# 24          501                                  Jct. 2 - Jct. 820       23.3
# 25          501                                  Jct. 4 - Jct. 500       10.2
# 26          501                                Jct. 500 - Jct. 879       19.7
# 27          505  Gulf Plant Access Road (Range Road 292) - Wate...       16.9
# 28          505      Waterton River - Range Road 271 (by Glenwood)       12.9
# 29          506                    Range Road 200 - Range Road 193        5.4
# 30          506   Range Road 193 (17.4 km West of Jct. 4) - Jct. 4       17.5
# 31          507                             Jct. 3 - Pincher Creek       33.1
# 32          507  Pincher Creek - 1.6 km West of Jct. 786 (Range...       14.2
# 33          508                                    Jct. 5 - Jct. 4        8.3
# 34          509  Jct. 2 - Range Road 240 (17.40 km East of Jct. 2)       17.4
# 35          512                              Lethbridge - Jct. 845       11.3
# 36          519                                Nobleford - Jct. 25       17.7
# 37          519                           Picture Butte - Jct. 845       12.2
#
# 0         75%        90%    Ban Off
# 1  2016-01-01        NaT        NaT
# 2  2016-04-24        NaT 2016-05-16
# 3  2016-02-11 2016-05-16        NaT
# 4  2016-04-24        NaT 2016-05-16
# 5         NaT 2016-03-14        NaT
# 6  2016-03-07 2016-05-16        NaT
# 7  2016-03-07        NaT 2016-05-16
# 8  2016-03-07        NaT 2016-06-06
# 9  2016-01-01        NaT        NaT
# 10 2016-02-11 2016-05-16        NaT
# 11 2016-02-11 2016-05-16        NaT
# 12 2016-02-11 2016-05-16        NaT
# 13        NaT 2016-03-14 2016-05-30
# 14 2016-03-14        NaT 2016-05-30
# 15        NaT 2016-03-14 2016-06-16
# 16        NaT 2016-03-14 2016-05-30
# 17 2016-03-24        NaT 2016-06-16
# 18 2016-03-10        NaT 2016-12-12
# 19        NaT 2016-03-07 2016-05-30
# 20        NaT 2016-02-11 2016-05-16
# 21 2016-01-01        NaT        NaT
# 22 2016-02-11 2016-05-16        NaT
# 23 2016-02-11 2016-05-16        NaT
# 24        NaT 2016-02-11 2016-05-16
# 25 2016-02-11        NaT 2016-05-16
# 26 2016-02-11 2016-05-16        NaT
# 27        NaT 2016-02-11 2016-05-16
# 28        NaT 2016-02-11 2016-05-16
# 29 2016-01-01        NaT        NaT
# 30 2016-01-01        NaT        NaT
# 31        NaT 2016-02-11 2016-05-16
# 32 2016-02-11        NaT 2016-05-16
# 33 2016-02-11        NaT 2016-05-16
# 34        NaT 2016-02-11 2016-05-16
# 35        NaT 2016-02-11 2016-05-16
# 36        NaT 2016-02-11 2016-05-16
# 37        NaT 2016-02-11 2016-05-16

# %%
# Unstacking the dataframe to the form in the most recent road ban summary report (Format 3)
data = []
for index, row in df.iterrows():
    if pd.notnull(row['75%']):
        data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['75%'],75])
    if pd.notnull(row['90%']):
        data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['90%'],90])
    if pd.notnull(row['Ban Off']):
        data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['Ban Off'],100])
pd.DataFrame(data, columns=['Road','Description','Distance','Effective Date','Percentage'])
# Out:
#            Road                                        Description Distance  \
# 0    127 Street  Ellerslie Road to Anthony Henday Drive in Edmo...      0.9
# 1   Jamieson Rd  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...      2.3
# 2   Jamieson Rd  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...      2.3
# 3            1A  0.6 km East of Jct. 1X - Jamieson Road (Range ...     27.9
# 4            1A  0.6 km East of Jct. 1X - Jamieson Road (Range ...     27.9
# ..          ...                                                ...      ...
# 63          512                              Lethbridge - Jct. 845     11.3
# 64          519                                Nobleford - Jct. 25     17.7
# 65          519                                Nobleford - Jct. 25     17.7
# 66          519                           Picture Butte - Jct. 845     12.2
# 67          519                           Picture Butte - Jct. 845     12.2
#
#    Effective Date  Percentage
# 0      2016-01-01          75
# 1      2016-04-24          75
# 2      2016-05-16         100
# 3      2016-02-11          75
# 4      2016-05-16          90
# ..            ...         ...
# 63     2016-05-16         100
# 64     2016-02-11          90
# 65     2016-05-16         100
# 66     2016-02-11          90
# 67     2016-05-16         100
#
# [68 rows x 5 columns]

# %% [markdown]
# ## Format 3: 2017 to Present
# Is created as a tabular format that stats the effective times of the various restrictions.

# %%
# Reading the pdf yields the following format
filename = 'trans-2020-road-ban-summary-list.pdf'
tables = read_pdf(f'./road ban summary lists/{filename}',pages='all')
tables
# Out:
# [   Jamieson Road  \
#  0            NaN
#  1             1A
#  2            NaN
#  3            NaN
#  4             1A
#  5            NaN
#  6            NaN
#  7            10X
#  8            NaN
#  9            NaN
#  10           10X
#  11           NaN
#  12            22
#  13           NaN
#  14            25
#  15            40
#  16           NaN
#  17           NaN
#  18            40
#  19           NaN
#  20            40
#  21           NaN
#  22           NaN
#  23            40
#
#     Jct. 1A - 2.3 km North (Stoney Indian Reserve #144 North Boundary)  \
#  0                                                 NaN
#  1   0.6 km East of Jct 1X - Jamieson Road (8.0 km ...
#  2                                                 NaN
#  3                                                 NaN
#  4   Jamieson Road (8.0 km West of Jct. 40) - Ghost...
#  5                                     Recreation Area
#  6                                                 NaN
#  7   km 0.05 (Bridge #9 at Wayne) - km 4.05 (Bridge...
#  8                                                 NaN
#  9                                                 NaN
#  10            km 4.05 (Bridge #2) - km 5.61 (Jct. 10)
#  11                                                NaN
#  12                              Mayerthorpe - Jct. 18
#  13                                                NaN
#  14                                Jct. 521 - Jct. 526
#  15  Cadomin Jct. (47.9 km S. of Jct. 16) - Teck Co...
#  16                            (39.9 km S. of Jct. 16)
#  17                                                NaN
#  18  Cadomin Junction (47.9 km South of Jct. 16) - ...
#  19                                                NaN
#  20   Jct. 1A - MD8 Boundary (7.8 km North of Jct. 1A)
#  21                                                NaN
#  22                                                NaN
#  23  Jct. 734 (1.3 km S of Lovett River) - 19.5 km ...
#
#       2.3 km  March 26, 2020     75%
#  0       NaN    June 4, 2020  Lifted
#  1   27.9 km    May 27, 2019     90%
#  2       NaN  March 26, 2020     75%
#  3       NaN    June 4, 2020     90%
#  4    3.7 km  March 26, 2020     75%
#  5       NaN             NaN     NaN
#  6       NaN    June 4, 2020  Lifted
#  7    4.5 km    May 30, 2019     90%
#  8       NaN  March 26, 2020     75%
#  9       NaN    June 8, 2020     90%
#  10   1.1 km  March 26, 2020     75%
#  11      NaN    June 8, 2020  Lifted
#  12   6.9 km  March 30, 2020     75%
#  13      NaN   June 11, 2020  Lifted
#  14  19.4 km   April 8, 2008     75%
#  15   9.5 km  March 30, 2020     90%
#  16      NaN             NaN     NaN
#  17      NaN    June 8, 2020  Lifted
#  18  29.4 km  March 30, 2020     90%
#  19      NaN    June 8, 2020  Lifted
#  20   7.8 km    May 27, 2019     90%
#  21      NaN  March 26, 2020     75%
#  22      NaN    June 4, 2020     90%
#  23  16.6 km  March 30, 2020     90%  ,
#                      40  \
#  0                  NaN
#  1                  NaN
#  2                  NaN
#  3                   40
#  4                  NaN
#  5                  NaN
#  6                  NaN
#  7                   56
#  8                  NaN
#  9                   58
#  10                 NaN
#  11                  66
#  12                 NaN
#  13  127 St. (Edmonton)
#  14                 500
#  15                 501
#  16                 NaN
#  17                 501
#  18                 NaN
#  19                 501
#  20                 NaN
#  21                 NaN
#  22                 501
#  23                 NaN
#  24                 NaN
#  25                 505
#
#     MD 8 Boundary (7.8 km North of Jct. 1A) - Richards Road (Range Road  \
#  0                                                 74)
#  1                                                 NaN
#  2                                                 NaN
#  3   Richards Road (Range Road 74) - Forest Reserve...
#  4                             North of Richards Road)
#  5                                                 NaN
#  6                                                 NaN
#  7                                   Jct. 9 - Stettler
#  8                                                 NaN
#  9   Wentzel River - Wood Buffalo National Park Wes...
#  10                                                NaN
#  11                               Ford Creek - Jct. 22
#  12                                                NaN
#  13            Jct. 216 - Ellerslie Road (in Edmonton)
#  14                   Range Road 153A - Range Road 135
#  15                                  Jct. 2 - Jct. 820
#  16                                                NaN
#  17                                  Jct. 4 - Jct. 500
#  18                                                NaN
#  19                                    Jct. 5 - Jct. 2
#  20                                                NaN
#  21                                                NaN
#  22                                Jct. 500 - Jct. 879
#  23                                                NaN
#  24                                                NaN
#  25  Gulf Plant Access Road (Range Road 292) - Wate...
#
#      16.1 km       May 27, 2019     90%
#  0       NaN                NaN     NaN
#  1       NaN     March 26, 2020     75%
#  2       NaN       June 4, 2020     90%
#  3    3.2 km       May 27, 2019     90%
#  4       NaN                NaN     NaN
#  5       NaN     March 26, 2020     75%
#  6       NaN       June 4, 2020     90%
#  7   73.7 km     March 26, 2020     90%
#  8       NaN       June 8, 2020  Lifted
#  9   41.7 km     April 24, 2020     75%
#  10      NaN  November 26, 2020  Lifted
#  11  27.6 km     March 26, 2020     90%
#  12      NaN       June 4, 2020  Lifted
#  13  .928 km      March 8, 2013     75%
#  14  19.4 km      April 8, 2008     75%
#  15  23.3 km      March 2, 2020     90%
#  16      NaN       June 4, 2020  Lifted
#  17  10.2 km      March 2, 2020     75%
#  18      NaN       June 4, 2020  Lifted
#  19  24.7 km       May 27, 2019     90%
#  20      NaN      March 2, 2020     75%
#  21      NaN       June 4, 2020     90%
#  22  19.7 km       May 27, 2019     90%
#  23      NaN      March 2, 2020     75%
#  24      NaN       June 4, 2020     90%
#  25  16.9 km      March 2, 2020     90%  ,
#        505      Waterton River - Range Road 271 (by Glenwood)  12.9 km  \
#  0     NaN                                                NaN      NaN
#  1   506.0                            Range Road 193 - Jct. 4  17.5 km
#  2     NaN                                                NaN      NaN
#  3   506.0                            Range Road 195 - Jct. 4  21.6 km
#  4   506.0                    Range Road 200 - Range Road 193   5.4 km
#                   Road                                        Description  \
#  0             UAR 187         Urban Access Road 187 (Jct. 21 - Swalwell)
#  1  Calling Lake Drive  Calling Lake Drive in the Jean Baptiste Gamble...
#  2    English Bay Road  English Bay Road through the Cold Lake Indian ...
#  3  FLMM - 8.5 km East  Frog Lake Massacre Monument - 8.5 km East in t...
#  4                 NaN                                       Reserve #121
#  5    Gurneyville Road  Gurneyville Road from Jct. 657 North in the Ke...
#  6        Nikoodi Road  Nikoodi Road Through the Alexis Indian Reserve...
#  7         Oiled Roads  Oiled Roads as posted in the Jean Baptiste Gam...
#
#    Distance    Effective Date Percentage
#  0   5.5 km  February 4, 2016        75%
#  1     2 km    April 13, 2020        75%
#  2      NaN  February 4, 2016        75%
#  3   8.5 km  February 4, 2016        75%
#  4      NaN               NaN        NaN
#  5      NaN  February 4, 2016        75%
#  6     9 km     June 17, 2019        75%
#  7      NaN  February 4, 2016        75%  ]

# %%
# Dataframe from the data table extraction
df = tables[0].T.reset_index().T.reset_index(drop=True)
df.columns = ['Road','Description','Distance','Effective Date','Percentage']
# Backfill the empty rows that are from the wrapped text
df.fillna(method='backfill', inplace=True)
df
# Out:
#              Road                                        Description Distance  \
# 0   Jamieson Road  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...   2.3 km
# 1              1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...  27.9 km
# 2              1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...  27.9 km
# 3              1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...   3.7 km
# 4              1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...   3.7 km
# 5              1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...   3.7 km
# 6             10X                                    Recreation Area   4.5 km
# 7             10X  km 0.05 (Bridge #9 at Wayne) - km 4.05 (Bridge...   4.5 km
# 8             10X  km 0.05 (Bridge #9 at Wayne) - km 4.05 (Bridge...   4.5 km
# 9             10X            km 4.05 (Bridge #2) - km 5.61 (Jct. 10)   1.1 km
# 10            10X            km 4.05 (Bridge #2) - km 5.61 (Jct. 10)   1.1 km
# 11            10X            km 4.05 (Bridge #2) - km 5.61 (Jct. 10)   1.1 km
# 12             22                              Mayerthorpe - Jct. 18   6.9 km
# 13             22                              Mayerthorpe - Jct. 18   6.9 km
# 14             25                                Jct. 521 - Jct. 526  19.4 km
# 15             25                                Jct. 521 - Jct. 526  19.4 km
# 16             40  Cadomin Jct. (47.9 km S. of Jct. 16) - Teck Co...   9.5 km
# 17             40                            (39.9 km S. of Jct. 16)  29.4 km
# 18             40  Cadomin Junction (47.9 km South of Jct. 16) - ...  29.4 km
# 19             40  Cadomin Junction (47.9 km South of Jct. 16) - ...  29.4 km
# 20             40   Jct. 1A - MD8 Boundary (7.8 km North of Jct. 1A)   7.8 km
# 21             40   Jct. 1A - MD8 Boundary (7.8 km North of Jct. 1A)   7.8 km
# 22             40  Jct. 734 (1.3 km S of Lovett River) - 19.5 km ...  16.6 km
# 23             40  Jct. 734 (1.3 km S of Lovett River) - 19.5 km ...  16.6 km
# 24             40  Jct. 734 (1.3 km S of Lovett River) - 19.5 km ...  16.6 km
#
#     Effective Date Percentage
# 0   March 26, 2020        75%
# 1     June 4, 2020     Lifted
# 2     May 27, 2019        90%
# 3   March 26, 2020        75%
# 4     June 4, 2020        90%
# 5   March 26, 2020        75%
# 6     June 4, 2020     Lifted
# 7     June 4, 2020     Lifted
# 8     May 30, 2019        90%
# 9   March 26, 2020        75%
# 10    June 8, 2020        90%
# 11  March 26, 2020        75%
# 12    June 8, 2020     Lifted
# 13  March 30, 2020        75%
# 14   June 11, 2020     Lifted
# 15   April 8, 2008        75%
# 16  March 30, 2020        90%
# 17    June 8, 2020     Lifted
# 18    June 8, 2020     Lifted
# 19  March 30, 2020        90%
# 20    June 8, 2020     Lifted
# 21    May 27, 2019        90%
# 22  March 26, 2020        75%
# 23    June 4, 2020        90%
# 24  March 30, 2020        90%

# %%
df = tables[1].T.reset_index().T.reset_index(drop=True)
df.columns = ['Road','Description','Distance','Effective Date','Percentage']
df.fillna(method='bfill', inplace=True)
df.sort_values(by=['Road','Effective Date'], ascending=True)
# Out:
#                   Road                                        Description  \
# 13  127 St. (Edmonton)            Jct. 216 - Ellerslie Road (in Edmonton)
# 14  127 St. (Edmonton)            Jct. 216 - Ellerslie Road (in Edmonton)
# 3                   40  Richards Road (Range Road 74) - Forest Reserve...
# 1                   40                                                74)
# 2                   40  Richards Road (Range Road 74) - Forest Reserve...
# 0                   40  MD 8 Boundary (7.8 km North of Jct. 1A) - Rich...
# 4                   40  Richards Road (Range Road 74) - Forest Reserve...
# 15                 500                   Range Road 153A - Range Road 135
# 17                 501                                  Jct. 4 - Jct. 500
# 19                 501                                    Jct. 5 - Jct. 2
# 22                 501                                Jct. 500 - Jct. 879
# 16                 501                                  Jct. 2 - Jct. 820
# 18                 501                                  Jct. 4 - Jct. 500
# 21                 501                                Jct. 500 - Jct. 879
# 20                 501                                    Jct. 5 - Jct. 2
# 23                 501                                Jct. 500 - Jct. 879
# 25                 505  Gulf Plant Access Road (Range Road 292) - Wate...
# 24                 505  Gulf Plant Access Road (Range Road 292) - Wate...
# 26                 505  Gulf Plant Access Road (Range Road 292) - Wate...
# 7                   56                                  Jct. 9 - Stettler
# 5                   56                            North of Richards Road)
# 6                   56                                  Jct. 9 - Stettler
# 8                   56                                  Jct. 9 - Stettler
# 10                  58  Wentzel River - Wood Buffalo National Park Wes...
# 9                   58  Wentzel River - Wood Buffalo National Park Wes...
# 12                  66                               Ford Creek - Jct. 22
# 11                  66                               Ford Creek - Jct. 22
#
#    Distance     Effective Date Percentage
# 13  .928 km       June 4, 2020     Lifted
# 14  .928 km      March 8, 2013        75%
# 3    3.2 km       June 4, 2020        90%
# 1    3.2 km     March 26, 2020        75%
# 2    3.2 km     March 26, 2020        75%
# 0   16.1 km       May 27, 2019        90%
# 4    3.2 km       May 27, 2019        90%
# 15  19.4 km      April 8, 2008        75%
# 17  10.2 km       June 4, 2020     Lifted
# 19  24.7 km       June 4, 2020     Lifted
# 22  19.7 km       June 4, 2020        90%
# 16  23.3 km      March 2, 2020        90%
# 18  10.2 km      March 2, 2020        75%
# 21  19.7 km      March 2, 2020        75%
# 20  24.7 km       May 27, 2019        90%
# 23  19.7 km       May 27, 2019        90%
# 25  16.9 km       June 4, 2020        90%
# 24  16.9 km      March 2, 2020        75%
# 26  16.9 km      March 2, 2020        90%
# 7   73.7 km       June 4, 2020        90%
# 5   73.7 km     March 26, 2020        75%
# 6   73.7 km     March 26, 2020        75%
# 8   73.7 km     March 26, 2020        90%
# 10  41.7 km     April 24, 2020        75%
# 9   41.7 km       June 8, 2020     Lifted
# 12  27.6 km     March 26, 2020        90%
# 11  27.6 km  November 26, 2020     Lifted

# %% [markdown]
# ## Consolidating all available tables in directory

# %% [markdown]
# ### Format 1: 2004 - 2013

# %%
# Using the pre-processing on the pdf report to format data into most recent format of road ban data
data = []
for f in rb_reports[:3]:
    pdf_tables = read_pdf(f'./road ban reports/{f}',pages='all')
    
    # Parsing pdf file for the effective date of the report
    pdfFileObj = open(f'./road ban reports/{f}','rb')
    pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
    text = pdfReader.getPage(0).extractText()
#     print(text.split('\n'))
#     eff_date = dt.datetime.strptime(', '.join([x for x in text.split('\n') if 'EFFECTIVE' in x][0].split('A.M. ')[-1].split(', ')[1:]),'%B %d, %Y')
    eff_date = re.findall('[A-Z][a-z]+ [0-9]+, [0-9]{4}',text)[0]
    eff_date = dt.datetime.strptime(eff_date,'%B %d, %Y')
    
    # Iterating through the pdf pages
    for i in range(len(pdf_tables)):
        df_temp = pdf_tables[i]
        df_temp.columns = ['Road','-','Description','Percentage']
        for index, row in df_temp.iterrows():
            if index < len(df_temp)-1:
                if pd.notnull(row['Road']):
                    if pd.isnull(df_temp.iloc[index+1]['Road']):
                        data.append([row['Road'],row['Description']+df_temp.iloc[index+1]['Description'],eff_date,row['Percentage']])
                    else:
                        if row['Percentage'] == 'AXLE WEIGHT':
                            continue
                        data.append([row['Road'],row['Description'],eff_date,row['Percentage']])
            if pd.isnull(row['Road']):
                continue
pd.DataFrame(data,columns=['Road','Description','Effective Date','Percentage'])
# Out:
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
#        Road                                        Description Effective Date  \
# 0        1A   Jct. 1X - Jamieson Road (8.0 km West of Jct. 40)     2004-04-19
# 1        2A     0.8 km N. of Jct. 54 - 4.0 km North of Jct. 54     2004-04-19
# 2        2A          Jct. 42 - Red Deer (Bettenson pit access)     2004-04-19
# 3        2A             Grimshaw - 2 km South of Jct. 2 (Roma)     2004-04-19
# 4        2A                  4.0 km North of Jct. 54 - Penhold     2004-04-19
# ..      ...                                                ...            ...
# 646      69                              Fort McMurray Airport     2004-05-10
# 647  Local:  The English Bay Road through the Cold Lake Ind...     2004-05-10
# 648  Local:  The Gurneyville Road from SH 657 North in the ...     2004-05-10
# 649  Local:  Oiled Roads as posted in the Calling Lake Indi...     2004-05-10
# 650  Local:  The Frog Lake Massacre Monument - 8.5 km East ...     2004-05-10
#
#     Percentage
# 0           75
# 1           90
# 2           75
# 3           90
# 4           75
# ..         ...
# 646        100
# 647         75
# 648         75
# 649         75
# 650         75
#
# [651 rows x 4 columns]

# %%
test_str = 'Alberta TransportationEFFECTIVE 2:00 P.M. Monday, April 19, 2004ORDER NO. 04 - ROAD - 15This Order rescinds Order No. 04 - ROAD - 14ALBERTA TRANSPORTATION'
re.findall('[0-9]+:[0-9]+ [A-Z].[A-Z]. [A-Z][a-z]+, [A-Z][a-z]+ [0-9]+, [0-9]{4}',test_str)
re.findall('[A-Z][a-z]+ [0-9]+, [0-9]{4}',test_str)
# Out:
# ['April 19, 2004']

# %%
data = []
for i in range(len(tables)):
    df_temp = tables[i]
    df_temp.columns = ['Road','-','Description','Percentage']
    for index, row in df_temp.iterrows():
        if index < len(df_temp)-1:
            if pd.notnull(row['Road']):
                if pd.isnull(df_temp.iloc[index+1]['Road']):
                    data.append([row['Road'],row['Description']+df_temp.iloc[index+1]['Description'],row['Percentage']])
                else:
                    if row['Percentage'] == 'AXLE WEIGHT':
                        continue
                    data.append([row['Road'],row['Description'],row['Percentage']])
        if pd.isnull(row['Road']):
            continue
df3 = pd.DataFrame(data,columns=['Road','Description','Percentage'])

# %% [markdown]
# ### Format 2: 2014 - 2017

# %%
data = []
for f in summary_lists[:3]:
    pdf_tables = read_pdf(f'./road ban summary lists/{f}',pages='all')
    year = int(f.split('-')[1])
    for i in range(len(pdf_tables)):
        df_temp = pdf_tables[i].T.reset_index(drop=True).set_index(0).T
        df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
        df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
        df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
        df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\.\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
        df_temp['Ban Off'] = df_temp['Ban Off'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
        df_temp['Ban Off'] = df_temp['Ban Off'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\.\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
        for index, row in df_temp.iterrows():
            if pd.notnull(row['75%']):
                data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['75%'],75])
            if pd.notnull(row['90%']):
                data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['90%'],90])
            if pd.notnull(row['Ban Off']):
                data.append([row['Highway'],row['Section'],row['Dist. (km)'],row['Ban Off'],100])
df = pd.DataFrame(data, columns=['Road','Description','Distance','Effective Date','Percentage'])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-459-8bcf52d3b1d2> in <module>
#       6         df_temp = pdf_tables[i].T.reset_index(drop=True).set_index(0).T
#       7         df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
# ----> 8         df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
#       9         df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
#      10         df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\.\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-459-8bcf52d3b1d2> in <lambda>(x)
#       6         df_temp = pdf_tables[i].T.reset_index(drop=True).set_index(0).T
#       7         df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
# ----> 8         df_temp['75%'] = df_temp['75%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
#       9         df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime(year,1,1) if x == 'all year' else x)
#      10         df_temp['90%'] = df_temp['90%'].apply(lambda x: dt.datetime.strptime(re.sub('[\.\(\.\)]','',x)+f' {year}','%b %d %Y') if type(x)==str else x)
#
# ~\anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~\anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data 'all year Mar 10 2014' does not match format '%b %d %Y'

# %%
print(re.sub('[\.\(\)]','','Mar. 10 2014'))
print(re.sub('{\.}','','Mar. 10 2014'))
# Out:
# Mar 10 2014
# Mar. 10 2014

# %% [markdown]
# ### Format 3: 2017 - Present

# %%
df = pd.DataFrame()

for f in summary_lists[3:]: # Only using summary_lists[3:] because formatting on the data in previous years is different
    pdf_tables = read_pdf(f'./road ban summary lists/{f}',pages='all')
    for i in range(len(pdf_tables)):
        df_temp = pdf_tables[i].T.reset_index().T.reset_index(drop=True)
        df_temp.columns = ['Road','Description','Distance','Effective Date','Percentage']
        df_temp.fillna(method='bfill', inplace=True)
        df = pd.concat([df,df_temp])
df = df.drop_duplicates()
df = df.iloc[1:].reset_index(drop=True)
df['Distance'] = df['Distance'].apply(lambda x: float(str(x).split(' ')[0]))
df['Effective Date'] = df['Effective Date'].apply(lambda x: dt.datetime.strptime(x,'%B %d, %Y') if type(x)==str else x)
df['Percentage'] = df['Percentage'].apply(lambda x: 100 if x=='Lifted' else int(re.sub('%','',str(x))))
df
# Out:
#                    Road                                        Description  \
# 0         Jamieson Road  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...
# 1                    1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...
# 2                    1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...
# 3                    1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...
# 4                    1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...
# ..                  ...                                                ...
# 767                 879                                 Jct. 501 - Jct. 61
# 768                 881                                  Jct. 29 - Jct. 28
# 769                 881                                  Jct. 29 - Jct. 28
# 770  Calling Lake Drive  Calling Lake Drive in the Jean Baptiste Gamble...
# 771        Nikoodi Road  Nikoodi Road Through the Alexis Indian Reserve...
#
#      Distance Effective Date  Percentage
# 0         2.3     2017-03-20          75
# 1        27.9     2017-05-26         100
# 2        27.9     2016-05-16          90
# 3         3.7     2017-03-20          75
# 4         3.7     2017-05-26          90
# ..        ...            ...         ...
# 767      29.2     2020-03-02          90
# 768      21.3     2020-06-04         100
# 769      21.3     2020-04-13          90
# 770       2.0     2020-04-13          75
# 771       9.0     2019-06-17          75
#
# [772 rows x 5 columns]

# %% [markdown]
# # Analysis
# Based on the available data in the road ban pdfs, we have the following information:
# * Highway / Road
# * Specific section of the road
# * Axle Weight Percentages (categorical)
# * Effective Date
#
# The valueable information users may want to know with more certainty is the timing of which type of road ban restriction will impact them. This analysis can provide a closer look into the statistics of such information.

# %% [markdown]
# ## Processing Data

# %% [markdown]
# What do I want to learn from this data?
# * Average date & distribution that road bans come into effect for each road / section & the various road ban levels
# * Effective dates over time for which road bans come into effect for each road / section & the various road ban levels

# %%
df['Key'] = df['Road'].apply(lambda x: str(x))+': '+df['Description']
# df['Key'] = df['Road'].apply(lambda x: str(x))+': '+df['Description']+' '+df['Percentage'].apply(lambda x: str(x))
df['Relative Offset'] = df['Effective Date'].apply(lambda x: x-dt.datetime(x.year,1,1))
df['Relative Date'] = dt.datetime(dt.datetime.today().year,1,1)+df['Relative Offset']
df
# Out:
#                    Road                                        Description  \
# 0         Jamieson Road  Jct. 1A - 2.3 km North (Stoney Indian Reserve ...
# 1                    1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...
# 2                    1A  0.6 km East of Jct 1X - Jamieson Road (8.0 km ...
# 3                    1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...
# 4                    1A  Jamieson Road (8.0 km West of Jct. 40) - Ghost...
# ..                  ...                                                ...
# 767                 879                                 Jct. 501 - Jct. 61
# 768                 881                                  Jct. 29 - Jct. 28
# 769                 881                                  Jct. 29 - Jct. 28
# 770  Calling Lake Drive  Calling Lake Drive in the Jean Baptiste Gamble...
# 771        Nikoodi Road  Nikoodi Road Through the Alexis Indian Reserve...
#
#      Distance Effective Date  Percentage  \
# 0         2.3     2017-03-20          75
# 1        27.9     2017-05-26         100
# 2        27.9     2016-05-16          90
# 3         3.7     2017-03-20          75
# 4         3.7     2017-05-26          90
# ..        ...            ...         ...
# 767      29.2     2020-03-02          90
# 768      21.3     2020-06-04         100
# 769      21.3     2020-04-13          90
# 770       2.0     2020-04-13          75
# 771       9.0     2019-06-17          75
#
#                                                    Key Relative Offset  \
# 0    Jamieson Road: Jct. 1A - 2.3 km North (Stoney ...         78 days
# 1    1A: 0.6 km East of Jct 1X - Jamieson Road (8.0...        145 days
# 2    1A: 0.6 km East of Jct 1X - Jamieson Road (8.0...        136 days
# 3    1A: Jamieson Road (8.0 km West of Jct. 40) - G...         78 days
# 4    1A: Jamieson Road (8.0 km West of Jct. 40) - G...        145 days
# ..                                                 ...             ...
# 767                          879.0: Jct. 501 - Jct. 61         61 days
# 768                           881.0: Jct. 29 - Jct. 28        155 days
# 769                           881.0: Jct. 29 - Jct. 28        103 days
# 770  Calling Lake Drive: Calling Lake Drive in the ...        103 days
# 771  Nikoodi Road: Nikoodi Road Through the Alexis ...        167 days
#
#     Relative Date
# 0      2021-03-20
# 1      2021-05-26
# 2      2021-05-17
# 3      2021-03-20
# 4      2021-05-26
# ..            ...
# 767    2021-03-03
# 768    2021-06-05
# 769    2021-04-14
# 770    2021-04-14
# 771    2021-06-17
#
# [772 rows x 8 columns]

# %% [markdown]
# ## Relative Offset & Relative Effective Dates

# %%
road_stats = df.groupby(by=['Key','Percentage'])['Road','Effective Date','Relative Offset'].describe()
road_stats
# Out:
# FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead. [ipykernel_launcher.py:1]
#                                                               Relative Offset  \
#                                                                         count
# Key                                                Percentage
# 10X: Recreation Area                               100                      2
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90                       4
#                                                    100                      3
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75                       4
#                                                    90                       4
# ...                                                                       ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100                      1
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75                       1
# nan: (South)                                       100                      1
# nan: 74)                                           75                       1
# nan: Lovett Riv Prov Rec Area)                     100                      1
#
#                                                                                  \
#                                                                            mean
# Key                                                Percentage
# 10X: Recreation Area                               100        150 days 12:00:00
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90         146 days 12:00:00
#                                                    100        196 days 00:00:00
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75          80 days 18:00:00
#                                                    90         152 days 06:00:00
# ...                                                                         ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100        202 days 00:00:00
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75          34 days 00:00:00
# nan: (South)                                       100        153 days 00:00:00
# nan: 74)                                           75          78 days 00:00:00
# nan: Lovett Riv Prov Rec Area)                     100        147 days 00:00:00
#
#                                                                                        \
#                                                                                   std
# Key                                                Percentage
# 10X: Recreation Area                               100         6 days 08:44:06.233050
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90          7 days 01:08:20.385941
#                                                    100        78 days 22:28:49.453316
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75          3 days 02:17:48.128942
#                                                    90          4 days 13:45:48.174739
# ...                                                                               ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100                            NaT
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75                             NaT
# nan: (South)                                       100                            NaT
# nan: 74)                                           75                             NaT
# nan: Lovett Riv Prov Rec Area)                     100                            NaT
#
#                                                                         \
#                                                                    min
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100        202 days
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75          34 days
# nan: (South)                                       100        153 days
# nan: 74)                                           75          78 days
# nan: Lovett Riv Prov Rec Area)                     100        147 days
#
# [374 rows x 8 columns]

# %%
# Using the offsets to calculate the varying Relative Date Statistics
road_stats['Mean Date'] = road_stats['Relative Offset']['mean']+dt.datetime(dt.datetime.today().year,1,1)
road_stats['Date Std'] = road_stats['Relative Offset']['std']
road_stats['Min Date'] = road_stats['Relative Offset']['min']+dt.datetime(dt.datetime.today().year,1,1)
road_stats['P25 Date'] = road_stats['Relative Offset']['25%']+dt.datetime(dt.datetime.today().year,1,1)
road_stats['P50 Date'] = road_stats['Relative Offset']['50%']+dt.datetime(dt.datetime.today().year,1,1)
road_stats['P75 Date'] = road_stats['Relative Offset']['75%']+dt.datetime(dt.datetime.today().year,1,1)
road_stats['Max Date'] = road_stats['Relative Offset']['max']+dt.datetime(dt.datetime.today().year,1,1)
road_stats[['Mean Date','Date Std','Min Date','P25 Date','P50 Date','P75 Date','Max Date']]
# Out:
#                                                                         Mean Date  \
#
# Key                                                Percentage
# 10X: Recreation Area                               100        2021-05-31 12:00:00
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90         2021-05-27 12:00:00
#                                                    100        2021-07-16 00:00:00
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75         2021-03-22 18:00:00
#                                                    90         2021-06-02 06:00:00
# ...                                                                           ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100        2021-07-22 00:00:00
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75         2021-02-04 00:00:00
# nan: (South)                                       100        2021-06-03 00:00:00
# nan: 74)                                           75         2021-03-20 00:00:00
# nan: Lovett Riv Prov Rec Area)                     100        2021-05-28 00:00:00
#
#                                                                              Date Std  \
#
# Key                                                Percentage
# 10X: Recreation Area                               100         6 days 08:44:06.233050
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90          7 days 01:08:20.385941
#                                                    100        78 days 22:28:49.453316
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75          3 days 02:17:48.128942
#                                                    90          4 days 13:45:48.174739
# ...                                                                               ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100                            NaT
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75                             NaT
# nan: (South)                                       100                            NaT
# nan: 74)                                           75                             NaT
# nan: Lovett Riv Prov Rec Area)                     100                            NaT
#
#                                                                 Min Date  \
#
# Key                                                Percentage
# 10X: Recreation Area                               100        2021-05-27
# 10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Br... 90         2021-05-17
#                                                    100        2021-05-27
# 10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)       75         2021-03-20
#                                                    90         2021-05-30
# ...                                                                  ...
# UAR 111: Urban Access Road 111 (Jct. 12 - Clive)   100        2021-07-22
# UAR 187: Urban Access Road 187 (Jct. 21 - Swalw... 75         2021-02-04
# nan: Lovett Riv Prov Rec Area)                     100        2021-05-28
#
# [374 rows x 7 columns]

# %% [markdown]
# ## Effective Date Distribution

# %%
plt.figure(figsize=(16,6))
sns.histplot(df['Effective Date'],kde=True)

# %% [markdown]
# ## Relative Date Distribution

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    sns.histplot(df[(df['Percentage']==pct)].sort_values(by=['Relative Date'],ascending=True)['Relative Date'], kde=True, label=f"{pct}%", color=pct_color)
plt.legend()

# %% [markdown]
# ## Relative Date over Time

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    try:
        sns.lineplot(x=df[df['Percentage']==pct]['Effective Date'].apply(lambda x: x.year), y=df[df['Percentage']==pct]['Relative Date'], label=f"{pct}%", color=pct_color)
    except:
        raise
plt.legend()

# %% [markdown]
# ## Specific Road Analysis
# Each road has its specific trends. Entering a road into the "key" variable below to view the road specific data

# %%
key = 'UAR 111: Urban Access Road 111 (Jct. 12 - Clive)'
print(df['Key'].unique())
# Out:
# ['Jamieson Road: Jct. 1A - 2.3 km North (Stoney Indian Reserve #144 North Boundary)'
#  '1A: 0.6 km East of Jct 1X - Jamieson Road (8.0 km West of Jct. 40)'
#  '1A: Jamieson Road (8.0 km West of Jct. 40) - Ghost Lake Provincial'
#  '2A: Recreation Area' '2A: Township Road 834 - Range Road 234'
#  '10X: km 0.05 (Bridge #9 at Wayne) - km 4.05 (Bridge #2)'
#  '10X: km 4.05 (Bridge #2) - km 5.61 (Jct. 10)'
#  '22: Mayerthorpe - Jct. 18' '25: Jct. 521 - Jct. 526'
#  '40: Cadomin Jct. (47.9 km S. of Jct. 16) - Teck Coal Cardinal Ops Access Rd'
#  '40: (39.9 km S. of Jct. 16)'
#  '40: Cadomin Junction (47.9 km South of Jct. 16) - 1.4 km South of Jct. 47'
#  '40: Jct. 1A - MD8 Boundary (7.8 km North of Jct. 1A)'
#  '40: Jct. 734 (1.3 km S of Lovett River) - 19.5 km S of Jct. 47 (100 m South of'
#  '40: MD 8 Boundary (7.8 km North of Jct. 1A) - Richards Road (Range Road'
#  'nan: 74)' nan
#  '505: Gulf Plant Access Road (Range Road 292) - Waterton River'
#  '505.0: Waterton River - Range Road 271 (by Glenwood)'
#  '506.0: Range Road 193 - Jct. 4' '506.0: Range Road 200 - Range Road 193'
#  '507.0: Jct. 3 - Pincher Creek'
#  '507.0: Pincher Creek - 1.6 km West of Jct. 786 (Range Road 290)'
#  '508.0: Jct. 5 - Jct. 4'
#  '509.0: Jct. 2 - Range Road 240 (17.4 km East of Jct. 2)'
#  '512.0: Lethbridge - Jct. 845' '519.0: Nobleford - Jct. 25'
#  '519.0: Picture Butte - Jct. 845'
#  '520.0: Range Road 283 - Claresholm Industrial Airport'
#  '521.0: 3.2 km East of Jct. 25 (Range Road 190) - Jct. 864'
#  '521.0: Jct. 25 - 3.2 km East of Jct. 25 (Range Road 190)'
#  'Oiled Roads: Oiled Roads as posted in the Jean Baptiste Gambler Indian Reserve #183'
#  '505: Waterton River - Range Road 271 (by Glenwood)'
#  '506.0: Range Road 195 - Jct. 4' '519.0: Jct. 25 - Jct. 845'
#  '586: Jct. 36 - Jct. 872' '752.0: Lovett River)'
#  '752.0: Forest Reserve Boundary (Range Road 100) - Strachan Plant'
#  '851: Jct. 576 - Jct. 9' '855.0: Heisler - Jct. 13 (Daysland)'
#  '855.0: Jct. 12 - Township Road 404' '855.0: Jct. 53 - Heisler'
#  '855.0: Jct. 589 - Jct. 12' '855.0: Jct. 663 - Jct. 63'
#  '861: 0.8 km North of Jct. 12 - 2.72 km North of Jct. 12'
#  'Calling Lake Drive: Calling Lake Drive in the Jean Baptiste Gambler Indian Reserve #183']

# %% [markdown]
# ### Relative Date Distribution

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    sns.histplot(df[(df['Key']==key) & (df['Percentage']==pct)].sort_values(by=['Relative Date'],ascending=True)['Relative Date'], kde=True, label=f"{pct}%", color=pct_color)
plt.legend()

# %% [markdown]
# ### Relative Offset Distribution

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    sns.histplot(df[(df['Key']==key) & (df['Percentage']==pct)].sort_values(by=['Relative Date'],ascending=True)['Relative Offset']/1000000000/86400, kde=True, label=f"{pct}%", color=pct_color)
plt.legend()

# %% [markdown]
# ## Time Series

# %%
key = '879.0: Jct. 501 - Jct. 61'
dft = df[df['Key']==key]
dft
# Out:
#     Road         Description  Distance Effective Date  Percentage  \
# 190  879  Jct. 501 - Jct. 61      29.2     2017-06-12         100
# 191  879  Jct. 501 - Jct. 61      29.2     2017-02-17          90
# 766  879  Jct. 501 - Jct. 61      29.2     2020-06-04         100
# 767  879  Jct. 501 - Jct. 61      29.2     2020-03-02          90
#
#                            Key Relative Offset Relative Date
# 190  879.0: Jct. 501 - Jct. 61        162 days    2021-06-12
# 191  879.0: Jct. 501 - Jct. 61         47 days    2021-02-17
# 766  879.0: Jct. 501 - Jct. 61        155 days    2021-06-05
# 767  879.0: Jct. 501 - Jct. 61         61 days    2021-03-03

# %% [markdown]
# ### Relative Date over Time

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    try:
        sns.lineplot(x=dft[dft['Percentage']==pct]['Effective Date'].apply(lambda x: x.year), y=dft[dft['Percentage']==pct]['Relative Date'], label=f"{pct}%", color=pct_color)
    except:
        raise
plt.legend()

# %% [markdown]
# ### Relative Offset over Time

# %%
plt.figure(figsize=(16,6))
pct_dict = {75:'red',90:'orange',100:'blue'}
for pct, pct_color in pct_dict.items():
    try:
        sns.lineplot(x=dft[dft['Percentage']==pct]['Effective Date'].apply(lambda x: x.year), y=dft[dft['Percentage']==pct]['Relative Offset']/1000000000/86400, label=f"{pct}%", color=pct_color)
    except:
        raise
plt.legend()
